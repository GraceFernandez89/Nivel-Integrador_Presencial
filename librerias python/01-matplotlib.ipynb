# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

excel = pd.read_csv(r'F:\2024\grupo intermedio\librerias python\finanzas.csv')
excel
vol = excel[excel.Categoría == 'Comestibles']
vol.Artículo.value_counts()
vol.Artículo.value_counts().plot()
# Out:
# <Axes: xlabel='Artículo'>

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

excel = pd.read_csv(r'F:\2024\grupo intermedio\librerias python\finanzas.csv')
excel
vol.head()
vol.Artículo.value_counts()
vol.Artículo.value_counts().plot()
vol['Artículo'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='Artículo'>

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

excel = pd.read_csv(r'F:\2024\grupo intermedio\librerias python\finanzas.csv')
excel
vol.head()
vol['Artículo'].value_counts().plot(kind='barh')
# Out:
# <Axes: ylabel='Artículo'>

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

excel = pd.read_csv(r'F:\2024\grupo intermedio\librerias python\finanzas.csv')

excel.plot(kind='scatter', x='Unidades', y='Ganancia')
# Out:
# <Axes: xlabel='Unidades', ylabel='Ganancia'>

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

excel = pd.read_csv(r'F:\2024\grupo intermedio\librerias python\finanzas.csv')
excel
vol.head()

vol.Artículo.value_counts()
vol['Artículo'].value_counts().plot(kind='bar', color='Orange')
# Out:
# <Axes: xlabel='Artículo'>
